# %% [markdown]
# <a href="https://www.kaggle.com/code/vasundharaanbalagan/1-python-variables?scriptVersionId=117460809" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **Variable: It is a place holder or container that will hold data for us. A variable points to a value and does not stores it.**

# %%
a = 10
print (a)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = 2.3456
print (b)
# Out:
# 2.3456

# %%
type (b)
# Out:
# float

# %%
c = "world"
print (c)
# Out:
# world

# %%
type (c)
# Out:
# str

# %% [markdown]
# **There are different types of variable, here a,b,and c have integer, float and string variable type respectively.******

# %% [markdown]
# **Numeric variables: integers (int), float (include fractions and decimals) and complex numbers (rarely used).**

# %%
d = 2+5J
print (d)
type (d)
# Out:
# (2+5j)
# complex

# %% [markdown]
# **Working with multiple variables**
#
# ### Always right hand side is agreegated first and the value is assigned to left side

# %%
gross_profit = 15
revenue = 100
gross_profit_margin = (gross_profit/revenue)*100
print (gross_profit_margin)
type (gross_profit_margin)
# Out:
# 15.0
# float

# %% [markdown]
# **note**: the assigned values are integer but result is float. It is because of the divide operation.

# %%
Revenue = 100
RevA = 8
Revenue = Revenue + RevA
print (Revenue)
# Out:
# 108

# %% [markdown]
# ### Variables with string
#
# strings can hold alphabets, numeric value, and special characters.
# we can combine two strings as single one using plus operator.**

# %%
address = "Tom, No-5, 5th cross street, Bangalore, Mol - 400053, Mobile No. - 999999999, Email ID - tom@gmail.com"
print (address)
# Out:
# Tom, No-5, 5th cross street, Bangalore, Mol - 400053, Mobile No. - 999999999, Email ID - tom@gmail.com

# %%
t = "hello"
u = "world"
v = t+ " "+u
print (v)
# Out:
# hello world

# %% [markdown]
# ### Variables with boolean
#
# Booleans can take only one of the 2 values: True or False (note: T and F are capital)

# %%
a = 3
b = 4
a>b
# Out:
# False

# %%
c = a<b
print (c)
type (c)
# Out:
# True
# bool

# %%
f = False
t = "False"
type (f)
# Out:
# bool

# %%
type (t)
# Out:
# str

# %% [markdown]
# ### Naming conversions of variable:
#
# **1. variable name always strarts with a alphabet.
# 2. it cannot have any special characters except underscore (_).
# 3. it cannot have space between them.
# 4. variable names are case sensitive.
# 5. cannot use RESERVED KEYWORDS, like: for, else, if, break, continue...
# **
# **note**: we can use # to include notes in code cell.

# %% [markdown]
# ## Print statement
#
# **1. print() is a function used to bring the output to console.
# 2. we can pass multiple variables inside print statement.
# **

# %%
a = 23
b = 100
print ("Tom scored", a,"and", b, "in math and science")
# Out:
# Tom scored 23 and 100 in math and science

# %% [markdown]
# ### Swaping variable
#
# **1. we create a temporary variable to swap the variables.**

# %%
g=66
h=45

# %%
j=g
g=h
h=j
print (g, "and", h)
# Out:
# 45 and 66
